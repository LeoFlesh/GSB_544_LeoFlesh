# %% [markdown]
# ---
# title: "Practice Acitivity Writing Functions"
# format:
#   html:
#     embed-resources: true
#     code-fold: true
# execute:
#   echo: true
#   warning: false
#   message: false
# ---

# %%
# !pip install palmerpenguins

# %%
import numpy as np
import pandas as pd
from sys import exit
from palmerpenguins import load_penguins
from plotnine import ggplot, aes, geom_point, geom_bar

# %% [markdown]
# 1. Fill in the necessary code to write a function called `times_seven()`. The function should take a single argument (`x`) and multiply the input by 7.
#   + This function should check that the argument is numeric.
#   + This function should also excitedly announce (print) *“I love sevens!”* if the argument to the function is a 7.

# %%
def times_seven(x):

  if not isinstance(x, (int, float)):
    exit("This is not numeric! Please input a numeric value")

  if x == 7:
    print("I love sevens!")

  return (x * 7)

# %% [markdown]
# 2. Write and run some *unit tests* for your `times_seven` function.  What happens if the input to the function is `[1, 3, 5, 7]`?

# %%
times_seven(1), times_seven(3), times_seven(5), times_seven(7)
# Out:
# I love sevens!
# (7, 21, 35, 49)

# %%
times_seven('bill_length_mm')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: This is not numeric! Please input a numeric value
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.

# %%
times_seven(True)
# Out:
# 7

# %%
times_seven()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-678309677.py in <cell line: 0>()
# ----> 1 times_seven()
#
# TypeError: times_seven() missing 1 required positional argument: 'x'

# %% [markdown]
# 3. Consider the following function:

# %%
def add_or_subtract(first_num, second_num = 2, type = "add"):

  if (type == "add"):
    res = first_num + second_num
  elif (type == "subtract"):
    res = first_num - second_num
  else:
    exit("Please choose `add` or `subtract` as the type.")

    return res

# %% [markdown]
# **Without running the code**, predict if the following will produce:
#
# a. 1
#
# b. -1
#
# c. 30
#
# d. An error defined by the function `add_or_subtract()`
#
# e. An error defined in a different function, which is called inside the `add_or_subtract()` function

# %%
add_or_subtract(5, 6, type = "subtract")

# %% [markdown]
# I think this would get -1 since it is correctly doing 5 - 6 = -1

# %%
add_or_subtract("orange")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-191245419.py in <cell line: 0>()
# ----> 1 add_or_subtract("orange")
#
# /tmp/ipython-input-811499585.py in add_or_subtract(first_num, second_num, type)
#       2
#       3   if (type == "add"):
# ----> 4     res = first_num + second_num
#       5   elif (type == "subtract"):
#       6     res = first_num - second_num
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# I think this would be e, since the error would come from python itself in not using the correct type

# %%
add_or_subtract(5, 6, type = "multiply")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Please choose `add` or `subtract` as the type.
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.

# %% [markdown]
# I think this would also be e, An error defined in a different function, which is called inside the add_or_subtract() function, since its still python not seeing the correct input choice

# %% [markdown]
# 4. Consider the following code:

# %%
first_num  = 5
second_num = 3

result = 8

result = add_or_subtract(first_num, second_num = 4)

result_2 = add_or_subtract(first_num)

# %% [markdown]
# In your Global Environment, what is the value of...
#
# a. `first_num`
#
# b. `second_num`
#
# c. `result`
#
# d. `result_2`

# %% [markdown]
# first_num = 5
# second_num = 3
# result = 8
# Then there would be no result 2 since it is all contained in the function and would not reach the global environment
